# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np
import torchvision
import matplotlib.pyplot as plt
import seaborn as sns
import torch.optim.lr_scheduler as lr_scheduler
from dataset import StoneDataset
import seaborn as sns
import random
from torch.utils.data import DataLoader
from torchvision.models import vit_b_16, ViT_B_16_Weights
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import f1_score
import pandas as pd

# %%
train_data = StoneDataset(root="./dataset/train_val", split="train", transforms=transforms.ToTensor())

train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
])

labels = train_data.labels
sns.countplot(x=labels)
plt.title("Class Distribution in Training Set")
# Out:
# Text(0.5, 1.0, 'Class Distribution in Training Set')

# %%
class_indices = {0: [], 1: [], 2: []}
for idx, label in enumerate(train_data.labels):
    class_indices[label].append(idx)

num_samples_per_class = 5
selected_indices = {}
for cls in class_indices:
    if len(class_indices[cls]) >= num_samples_per_class:
        selected_indices[cls] = random.sample(class_indices[cls], num_samples_per_class)
    else:
        selected_indices[cls] = class_indices[cls]

# 直接转换张量为 PIL 图像（无需反归一化）
def tensor_to_pil(tensor):
    return transforms.ToPILImage()(tensor.cpu().clone().squeeze(0))

# 显示图像
fig, axes = plt.subplots(len(selected_indices), num_samples_per_class, figsize=(15, 8))
for cls_idx, cls in enumerate(selected_indices):
    for i, idx in enumerate(selected_indices[cls]):
        img, label = train_data[idx]
        img_pil = tensor_to_pil(img)  # 直接转换
        ax = axes[cls_idx, i]
        ax.imshow(img_pil)
        ax.axis('off')
        ax.set_title(f'Class {cls}')
plt.tight_layout()
plt.show()

# %%
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# 创建DataLoader
batch_size = 128
train_loader = DataLoader(
    StoneDataset(root="./dataset/train_val", split="train", transforms=train_transform),
    batch_size=batch_size, shuffle=True, num_workers=4
)
val_loader = DataLoader(
    StoneDataset(root="./dataset/train_val", split="val", transforms=val_transform),
    batch_size=batch_size, shuffle=False, num_workers=4
)

# %%
# def build_efficientnet(num_classes=3, pretrained=True):
#     weights = EfficientNet_B0_Weights.IMAGENET1K_V1 if pretrained else None
#     model = efficientnet_b0(weights=weights)
#     # 调整分类器
#     in_features = model.classifier[1].in_features
#     model.classifier[1] = nn.Linear(in_features, num_classes)
#     return model

from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights

def build_efficientnet(num_classes=3, pretrained=True, local_weight_path=None):
    if pretrained and local_weight_path:
        # 加载无预训练模型
        model = efficientnet_b0(weights=None)
        state_dict = torch.load(local_weight_path, map_location='cpu')
        model.load_state_dict(state_dict)
    else:
        weights = EfficientNet_B0_Weights.IMAGENET1K_V1 if pretrained else None
        model = efficientnet_b0(weights=weights)

    # 修改分类器头部
    in_features = model.classifier[1].in_features
    model.classifier[1] = torch.nn.Linear(in_features, num_classes)

    return model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train_labels = train_data.labels
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=50):
    model = model.to(device)
    best_acc = 0.0
    train_losses, val_losses, val_accs,val_f1 = [], [], [],[]
    
    for epoch in range(num_epochs):
        # 训练阶段
        print(epoch)
        model.train()
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
        epoch_loss = running_loss / len(train_loader.dataset)
        train_losses.append(epoch_loss)
        
        # 验证阶段
        val_loss, val_acc, val_f1_score = evaluate(model, val_loader, criterion)
        val_losses.append(val_loss)
        val_f1.append(val_f1_score)
        val_accs.append(val_acc)
        
        # 保存最佳模型
        if val_acc > best_acc:
            best_acc = val_acc
            torch.save(model.state_dict(), 'best_model.pth')
        
        print(f'Epoch {epoch+1}/{num_epochs} | Train Loss: {epoch_loss:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.2%} | Val F1: {val_f1_score:.4f}')  # 新增 F1
    
    history = {'train_loss': train_losses, 'val_loss': val_losses, 'val_acc': val_accs, 'val_f1': val_f1}
    return model, history

# %%
def evaluate(model, data_loader, criterion):
    model.eval()
    total_loss = 0.0
    correct = 0
    all_preds, all_labels = [], []
    
    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    avg_loss = total_loss / len(data_loader.dataset)
    accuracy = correct / len(data_loader.dataset)
    f1 = f1_score(all_labels, all_preds, average='weighted')
    
    return avg_loss, accuracy, f1

# %%
local_weight_path = "efficientnet_b0_rwightman-7f5810bc.pth"
model = build_efficientnet(num_classes=3, pretrained=True, local_weight_path=local_weight_path)
optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=50)
# Out:
# /tmp/ipykernel_47704/2612212995.py:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(local_weight_path, map_location='cpu')

# %%
# model = build_efficientnet(num_classes=3, pretrained=False)
# optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4)
# scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=50)

# %%
# 训练模型
model, history = train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=50
)
# Out:
# 0
# Epoch 1/50 | Train Loss: 0.8118 | Val Loss: 0.7124 | Val Acc: 68.00% | Val F1: 0.6810
# 1
# Epoch 2/50 | Train Loss: 0.7300 | Val Loss: 0.6717 | Val Acc: 70.81% | Val F1: 0.7087
# 2
# Epoch 3/50 | Train Loss: 0.6889 | Val Loss: 0.6354 | Val Acc: 72.61% | Val F1: 0.7273
# 3
# Epoch 4/50 | Train Loss: 0.6593 | Val Loss: 0.6161 | Val Acc: 73.40% | Val F1: 0.7339
# 4
# Epoch 5/50 | Train Loss: 0.6372 | Val Loss: 0.6036 | Val Acc: 74.87% | Val F1: 0.7490
# 5
# Epoch 6/50 | Train Loss: 0.6178 | Val Loss: 0.6000 | Val Acc: 75.35% | Val F1: 0.7543
# 6
# Epoch 7/50 | Train Loss: 0.5981 | Val Loss: 0.5951 | Val Acc: 75.36% | Val F1: 0.7542
# 7
# Epoch 8/50 | Train Loss: 0.5780 | Val Loss: 0.5938 | Val Acc: 75.51% | Val F1: 0.7557
# 8
# Epoch 9/50 | Train Loss: 0.5634 | Val Loss: 0.6039 | Val Acc: 75.26% | Val F1: 0.7517
# 9
# Epoch 10/50 | Train Loss: 0.5453 | Val Loss: 0.5933 | Val Acc: 76.07% | Val F1: 0.7604
# 10
# Epoch 11/50 | Train Loss: 0.5372 | Val Loss: 0.5814 | Val Acc: 76.17% | Val F1: 0.7622
# 11
# Epoch 12/50 | Train Loss: 0.5176 | Val Loss: 0.5913 | Val Acc: 76.15% | Val F1: 0.7617
# 12
# Epoch 13/50 | Train Loss: 0.5078 | Val Loss: 0.5955 | Val Acc: 76.57% | Val F1: 0.7656
# 13
# Epoch 14/50 | Train Loss: 0.4939 | Val Loss: 0.5971 | Val Acc: 77.05% | Val F1: 0.7706
# 14
# Epoch 15/50 | Train Loss: 0.4826 | Val Loss: 0.6130 | Val Acc: 76.83% | Val F1: 0.7688
# 15
# Epoch 16/50 | Train Loss: 0.4687 | Val Loss: 0.6172 | Val Acc: 76.49% | Val F1: 0.7645
# 16
# Epoch 17/50 | Train Loss: 0.4591 | Val Loss: 0.6295 | Val Acc: 76.20% | Val F1: 0.7620
# 17
# Epoch 18/50 | Train Loss: 0.4478 | Val Loss: 0.6351 | Val Acc: 76.12% | Val F1: 0.7612
# 18
# Epoch 19/50 | Train Loss: 0.4361 | Val Loss: 0.6455 | Val Acc: 76.84% | Val F1: 0.7687
# 19
# Epoch 20/50 | Train Loss: 0.4280 | Val Loss: 0.6321 | Val Acc: 76.65% | Val F1: 0.7671
# 20
# Epoch 21/50 | Train Loss: 0.4183 | Val Loss: 0.6464 | Val Acc: 76.75% | Val F1: 0.7677
# 21
# Epoch 22/50 | Train Loss: 0.4088 | Val Loss: 0.6752 | Val Acc: 76.43% | Val F1: 0.7640
# 22
# Epoch 23/50 | Train Loss: 0.3987 | Val Loss: 0.6811 | Val Acc: 76.93% | Val F1: 0.7690
# 23
# Epoch 24/50 | Train Loss: 0.3911 | Val Loss: 0.6733 | Val Acc: 76.47% | Val F1: 0.7651
# 24
# Epoch 25/50 | Train Loss: 0.3855 | Val Loss: 0.6872 | Val Acc: 76.86% | Val F1: 0.7685
# 25
# Epoch 26/50 | Train Loss: 0.3770 | Val Loss: 0.7202 | Val Acc: 76.08% | Val F1: 0.7598
# 26
# Epoch 27/50 | Train Loss: 0.3673 | Val Loss: 0.7340 | Val Acc: 76.40% | Val F1: 0.7631
# 27
# Epoch 28/50 | Train Loss: 0.3600 | Val Loss: 0.7134 | Val Acc: 76.89% | Val F1: 0.7687
# 28
# Epoch 29/50 | Train Loss: 0.3523 | Val Loss: 0.7327 | Val Acc: 76.61% | Val F1: 0.7650
# 29
# Epoch 30/50 | Train Loss: 0.3465 | Val Loss: 0.7359 | Val Acc: 76.45% | Val F1: 0.7644
# 30
# Epoch 31/50 | Train Loss: 0.3408 | Val Loss: 0.7278 | Val Acc: 76.45% | Val F1: 0.7635
# 31
# Epoch 32/50 | Train Loss: 0.3353 | Val Loss: 0.7687 | Val Acc: 76.47% | Val F1: 0.7637
# 32
# Epoch 33/50 | Train Loss: 0.3311 | Val Loss: 0.7562 | Val Acc: 76.90% | Val F1: 0.7687
# 33
# Epoch 34/50 | Train Loss: 0.3232 | Val Loss: 0.7789 | Val Acc: 76.69% | Val F1: 0.7667
# 34
# Epoch 35/50 | Train Loss: 0.3192 | Val Loss: 0.7988 | Val Acc: 76.49% | Val F1: 0.7647
# 35
# Epoch 36/50 | Train Loss: 0.3182 | Val Loss: 0.7839 | Val Acc: 76.34% | Val F1: 0.7630
# 36
# Epoch 37/50 | Train Loss: 0.3123 | Val Loss: 0.7898 | Val Acc: 76.49% | Val F1: 0.7638
# 37
# Epoch 38/50 | Train Loss: 0.3087 | Val Loss: 0.8230 | Val Acc: 76.58% | Val F1: 0.7653
# 38
# Epoch 39/50 | Train Loss: 0.3046 | Val Loss: 0.8309 | Val Acc: 76.16% | Val F1: 0.7606
# 39
# Epoch 40/50 | Train Loss: 0.2972 | Val Loss: 0.8049 | Val Acc: 76.50% | Val F1: 0.7643
# 40
# Epoch 41/50 | Train Loss: 0.2926 | Val Loss: 0.8664 | Val Acc: 76.11% | Val F1: 0.7600
# 41
# Epoch 42/50 | Train Loss: 0.2893 | Val Loss: 0.8322 | Val Acc: 76.25% | Val F1: 0.7609
# 42
# Epoch 43/50 | Train Loss: 0.2868 | Val Loss: 0.8269 | Val Acc: 77.17% | Val F1: 0.7713
# 43
# Epoch 44/50 | Train Loss: 0.2838 | Val Loss: 0.8484 | Val Acc: 76.81% | Val F1: 0.7666
# 44
# Epoch 45/50 | Train Loss: 0.2803 | Val Loss: 0.8697 | Val Acc: 76.58% | Val F1: 0.7661
# 45
# Epoch 46/50 | Train Loss: 0.2776 | Val Loss: 0.8671 | Val Acc: 75.99% | Val F1: 0.7583
# 46
# Epoch 47/50 | Train Loss: 0.2719 | Val Loss: 0.9003 | Val Acc: 76.37% | Val F1: 0.7634
# 47
# Epoch 48/50 | Train Loss: 0.2722 | Val Loss: 0.8797 | Val Acc: 76.55% | Val F1: 0.7644
# 48
# Epoch 49/50 | Train Loss: 0.2664 | Val Loss: 0.8866 | Val Acc: 76.91% | Val F1: 0.7688
# 49
# Epoch 50/50 | Train Loss: 0.2640 | Val Loss: 0.9011 | Val Acc: 76.04% | Val F1: 0.7593

# %%
# 训练模型
model, history = train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=50
)
# Out:
# 0
# Epoch 1/50 | Train Loss: 0.9993 | Val Loss: 0.9615 | Val Acc: 50.75% | Val F1: 0.4926
# 1
# Epoch 2/50 | Train Loss: 0.9650 | Val Loss: 0.9077 | Val Acc: 55.11% | Val F1: 0.5495
# 2
# Epoch 3/50 | Train Loss: 0.9411 | Val Loss: 0.8849 | Val Acc: 56.27% | Val F1: 0.5588
# 3
# Epoch 4/50 | Train Loss: 0.9222 | Val Loss: 0.8580 | Val Acc: 58.03% | Val F1: 0.5793
# 4
# Epoch 5/50 | Train Loss: 0.9049 | Val Loss: 0.8616 | Val Acc: 58.38% | Val F1: 0.5821
# 5
# Epoch 6/50 | Train Loss: 0.8905 | Val Loss: 0.8336 | Val Acc: 60.60% | Val F1: 0.6053
# 6
# Epoch 7/50 | Train Loss: 0.8783 | Val Loss: 0.8172 | Val Acc: 61.02% | Val F1: 0.6112
# 7
# Epoch 8/50 | Train Loss: 0.8687 | Val Loss: 0.8178 | Val Acc: 61.16% | Val F1: 0.6096
# 8
# Epoch 9/50 | Train Loss: 0.8585 | Val Loss: 0.7958 | Val Acc: 62.19% | Val F1: 0.6224
# 9
# Epoch 10/50 | Train Loss: 0.8511 | Val Loss: 0.7928 | Val Acc: 62.77% | Val F1: 0.6282
# 10
# Epoch 11/50 | Train Loss: 0.8419 | Val Loss: 0.7811 | Val Acc: 63.75% | Val F1: 0.6369
# 11
# Epoch 12/50 | Train Loss: 0.8338 | Val Loss: 0.7634 | Val Acc: 64.51% | Val F1: 0.6425
# 12
# Epoch 13/50 | Train Loss: 0.8253 | Val Loss: 0.7634 | Val Acc: 64.78% | Val F1: 0.6474
# 13
# Epoch 14/50 | Train Loss: 0.8171 | Val Loss: 0.7573 | Val Acc: 65.17% | Val F1: 0.6521
# 14
# Epoch 15/50 | Train Loss: 0.8105 | Val Loss: 0.7486 | Val Acc: 65.79% | Val F1: 0.6562
# 15
# Epoch 16/50 | Train Loss: 0.8053 | Val Loss: 0.7391 | Val Acc: 66.23% | Val F1: 0.6615
# 16
# Epoch 17/50 | Train Loss: 0.8005 | Val Loss: 0.7634 | Val Acc: 64.53% | Val F1: 0.6446
# 17
# Epoch 18/50 | Train Loss: 0.7954 | Val Loss: 0.7432 | Val Acc: 65.92% | Val F1: 0.6601
# 18
# Epoch 19/50 | Train Loss: 0.7887 | Val Loss: 0.7431 | Val Acc: 66.17% | Val F1: 0.6615
# 19
# Epoch 20/50 | Train Loss: 0.7827 | Val Loss: 0.7237 | Val Acc: 67.27% | Val F1: 0.6723
# 20
# Epoch 22/50 | Train Loss: 0.7723 | Val Loss: 0.7107 | Val Acc: 68.19% | Val F1: 0.6829
# 22
# Epoch 23/50 | Train Loss: 0.7719 | Val Loss: 0.7103 | Val Acc: 68.21% | Val F1: 0.6825
# 23
# Epoch 24/50 | Train Loss: 0.7641 | Val Loss: 0.7032 | Val Acc: 68.66% | Val F1: 0.6859
# 24
# Epoch 25/50 | Train Loss: 0.7605 | Val Loss: 0.7003 | Val Acc: 68.52% | Val F1: 0.6851
# 25
# Epoch 26/50 | Train Loss: 0.7559 | Val Loss: 0.7172 | Val Acc: 67.26% | Val F1: 0.6738
# 26
# Epoch 27/50 | Train Loss: 0.7512 | Val Loss: 0.6990 | Val Acc: 68.86% | Val F1: 0.6894
# 27
# Epoch 28/50 | Train Loss: 0.7461 | Val Loss: 0.6934 | Val Acc: 69.24% | Val F1: 0.6926
# 28
# Epoch 29/50 | Train Loss: 0.7416 | Val Loss: 0.6845 | Val Acc: 69.68% | Val F1: 0.6976
# 29
# Epoch 30/50 | Train Loss: 0.7401 | Val Loss: 0.6904 | Val Acc: 68.97% | Val F1: 0.6905
# 30
# Epoch 31/50 | Train Loss: 0.7332 | Val Loss: 0.6852 | Val Acc: 69.87% | Val F1: 0.6992
# 31
# Epoch 32/50 | Train Loss: 0.7325 | Val Loss: 0.6778 | Val Acc: 69.67% | Val F1: 0.6969
# 32
# Epoch 33/50 | Train Loss: 0.7285 | Val Loss: 0.6799 | Val Acc: 70.02% | Val F1: 0.7002
# 33
# Epoch 34/50 | Train Loss: 0.7233 | Val Loss: 0.6703 | Val Acc: 70.33% | Val F1: 0.7026
# 34
# Epoch 35/50 | Train Loss: 0.7187 | Val Loss: 0.6674 | Val Acc: 70.69% | Val F1: 0.7072
# 35
# Epoch 36/50 | Train Loss: 0.7159 | Val Loss: 0.6651 | Val Acc: 70.43% | Val F1: 0.7045
# 36
# Epoch 37/50 | Train Loss: 0.7122 | Val Loss: 0.6709 | Val Acc: 70.26% | Val F1: 0.7029
# 37
# Epoch 38/50 | Train Loss: 0.7115 | Val Loss: 0.6573 | Val Acc: 71.10% | Val F1: 0.7113
# 38
# Epoch 39/50 | Train Loss: 0.7050 | Val Loss: 0.6576 | Val Acc: 71.49% | Val F1: 0.7145
# 39
# Epoch 40/50 | Train Loss: 0.7044 | Val Loss: 0.6568 | Val Acc: 70.91% | Val F1: 0.7090
# 40
# Epoch 41/50 | Train Loss: 0.6956 | Val Loss: 0.6724 | Val Acc: 70.34% | Val F1: 0.7034
# 41
# Epoch 42/50 | Train Loss: 0.6950 | Val Loss: 0.6593 | Val Acc: 71.22% | Val F1: 0.7131
# 42
# Epoch 43/50 | Train Loss: 0.6927 | Val Loss: 0.6510 | Val Acc: 71.87% | Val F1: 0.7191
# 43
# Epoch 44/50 | Train Loss: 0.6898 | Val Loss: 0.6523 | Val Acc: 71.59% | Val F1: 0.7157
# 44
# Epoch 45/50 | Train Loss: 0.6864 | Val Loss: 0.6518 | Val Acc: 72.11% | Val F1: 0.7216
# 45
# Epoch 46/50 | Train Loss: 0.6829 | Val Loss: 0.6406 | Val Acc: 72.21% | Val F1: 0.7224
# 46
# Epoch 47/50 | Train Loss: 0.6776 | Val Loss: 0.6432 | Val Acc: 72.19% | Val F1: 0.7220
# 47
# Epoch 48/50 | Train Loss: 0.6773 | Val Loss: 0.6517 | Val Acc: 71.82% | Val F1: 0.7181
# 48
# Epoch 49/50 | Train Loss: 0.6767 | Val Loss: 0.6435 | Val Acc: 72.23% | Val F1: 0.7223
# 49
# Epoch 50/50 | Train Loss: 0.6691 | Val Loss: 0.6414 | Val Acc: 72.15% | Val F1: 0.7222

# %%
def predict(model, test_loader):
    model.eval()
    filenames = []
    predictions = []
    
    with torch.no_grad():
        for images, paths in test_loader:
            images = images.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            filenames.extend(list(paths))
            predictions.extend(preds.cpu().numpy())
    return filenames, predictions

test_loader = DataLoader(
    StoneDataset(root="./dataset/test", split="test", transforms=val_transform),
    batch_size=batch_size, shuffle=False
)

filenames, preds = predict(model, test_loader)

# %%
df = pd.DataFrame({"filename": filenames, "label": preds})
df.to_csv("submission2new.csv", index=False)

# %%
# df = pd.DataFrame({"filename": filenames, "label": preds})
# df.to_csv("submission2.csv", index=False)

# %%
import matplotlib.pyplot as plt
def plot_training_log():
    epochs = list(range(1, 51))  # 共50个epoch

    train_loss = [
        0.9993, 0.9650, 0.9411, 0.9222, 0.9049, 0.8905, 0.8783, 0.8687, 0.8585, 0.8511,
        0.8419, 0.8338, 0.8253, 0.8171, 0.8105, 0.8053, 0.8005, 0.7954, 0.7887, 0.7827,
        0.7775, 0.7723, 0.7719, 0.7641, 0.7605, 0.7559, 0.7512, 0.7461, 0.7416, 0.7401,
        0.7332, 0.7325, 0.7285, 0.7233, 0.7187, 0.7159, 0.7122, 0.7115, 0.7050, 0.7044,
        0.6956, 0.6950, 0.6927, 0.6898, 0.6864, 0.6829, 0.6776, 0.6773, 0.6767, 0.6691
    ]
    
    val_loss = [
        0.9615, 0.9077, 0.8849, 0.8580, 0.8616, 0.8336, 0.8172, 0.8178, 0.7958, 0.7928,
        0.7811, 0.7634, 0.7634, 0.7573, 0.7486, 0.7391, 0.7634, 0.7432, 0.7431, 0.7237,
        0.7172, 0.7107, 0.7103, 0.7032, 0.7003, 0.7172, 0.6990, 0.6934, 0.6845, 0.6904,
        0.6852, 0.6778, 0.6799, 0.6703, 0.6674, 0.6651, 0.6709, 0.6573, 0.6576, 0.6568,
        0.6724, 0.6593, 0.6510, 0.6523, 0.6518, 0.6406, 0.6432, 0.6517, 0.6435, 0.6414
    ]

    plt.figure(figsize=(12, 7))

    plt.plot(epochs, train_loss, label='Train Loss', color='purple', linewidth=2)
    plt.plot(epochs, val_loss, label='Val Loss', color='red', linewidth=2)
    plt.title('Efficient Model Training History')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
plot_training_log()
